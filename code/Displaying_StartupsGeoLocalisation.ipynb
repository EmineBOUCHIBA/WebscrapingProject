# %%
import pandas as pd
import folium

def load_coordinates():
    path = "C:\\Users\\emine\\Documents\\Ecole\\A5\\Webscraping & Data Processing\\Project\\data\\startup_coordinates.xlsx"
    data = pd.read_excel(path)
    return data

df_coordinates = load_coordinates()

map = folium.Map(location=[20, 0], zoom_start=2)

for _, row in df_coordinates.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['name']).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65e23a90628a36e5c86aff245cfdce84 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65e23a90628a36e5c86aff245cfdce84&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65e23a90628a36e5c86aff245cfdce84 = L.map(
#                 &quot;map_65e23a90628a36e5c86aff245cfdce84&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3faac674cff0947a34b85475eab169ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3faac674cff0947a34b85475eab169ec.addTo(map_65e23a90628a36e5c86aff245cfdce84);
#
#
#             var marker_46f1ebcf20ac01d79a9ee3a8ff236fe2 = L.marker(
#                 [49.4093582, 8.694724],
#                 {}
#             ).addTo(map_65e23a90628a36e5c86aff245cfdce84);
#
#
#         var popup_caa2635097439a4e99af73ff2dedb238 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b64dca1c709a62ed20f5c1cf5909c28 = $(`&lt;div id=&quot;html_4b64dca1c709a62ed20f5c1cf5909c28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PixelBiotech GmbH ​&lt;/div&gt;`)[0];
#                 popup_caa2635097439a4e99af73ff2dedb238.setContent(html_4b64dca1c709a62ed20f5c1cf5909c28);
#
#
#
#         marker_46f1ebcf20ac01d79a9ee3a8ff236fe2.bindPopup(popup_caa2635097439a4e99af73ff2dedb238)
#         ;
#
#
#
#
#             var marker_98c02eead6af6e3ef5ef085e915ec3d6 = L.marker(
#                 [49.4892913, 8.4673098],
#                 {}
#             ).addTo(map_65e23a90628a36e5c86aff245cfdce84);
#
#
#         var popup_2ea48ef309dc689102ead0da089be205 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b98c43e0a631fc9894d2736f9b9988b4 = $(`&lt;div id=&quot;html_b98c43e0a631fc9894d2736f9b9988b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tcelltech GmbH&lt;/div&gt;`)[0];
#                 popup_2ea48ef309dc689102ead0da089be205.setContent(html_b98c43e0a631fc9894d2736f9b9988b4);
#
#
#
#         marker_98c02eead6af6e3ef5ef085e915ec3d6.bindPopup(popup_2ea48ef309dc689102ead0da089be205)
#         ;
#
#
#
#
#             var marker_edf0c075be38f7caa8011be8efcca032 = L.marker(
#                 [51.9625101, 7.6251879],
#                 {}
#             ).addTo(map_65e23a90628a36e5c86aff245cfdce84);
#
#
#         var popup_e6b0c9cb8e7410d07c6232db54c199c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b4f943c6388764aec74e52076609be9 = $(`&lt;div id=&quot;html_8b4f943c6388764aec74e52076609be9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Trialflow GmbH&lt;/div&gt;`)[0];
#                 popup_e6b0c9cb8e7410d07c6232db54c199c4.setContent(html_8b4f943c6388764aec74e52076609be9);
#
#
#
#         marker_edf0c075be38f7caa8011be8efcca032.bindPopup(popup_e6b0c9cb8e7410d07c6232db54c199c4)
#         ;
#
#
#
#
#             var marker_b9f83c0b76169ea390a4c91187f62e74 = L.marker(
#                 [46.3144754, 11.0480288],
#                 {}
#             ).addTo(map_65e23a90628a36e5c86aff245cfdce84);
#
#
#         var popup_d13c77787b31c0c45d2841db74622d1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0add9d52716ab7b3b6d5e59016a69873 = $(`&lt;div id=&quot;html_0add9d52716ab7b3b6d5e59016a69873&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Trialzen&lt;/div&gt;`)[0];
#                 popup_d13c77787b31c0c45d2841db74622d1d.setContent(html_0add9d52716ab7b3b6d5e59016a69873);
#
#
#
#         marker_b9f83c0b76169ea390a4c91187f62e74.bindPopup(popup_d13c77787b31c0c45d2841db74622d1d)
#         ;
#
#
#
#
#             var marker_e816287f0a812e5dfe2c7b89ee35dcaa = L.marker(
#                 [46.3144754, 11.0480288],
#                 {}
#             ).addTo(map_65e23a90628a36e5c86aff245cfdce84);
#
#
#         var popup_4b3ecc48913be159af931ad4656715fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5063476c22092b7ca445756a541430b3 = $(`&lt;div id=&quot;html_5063476c22092b7ca445756a541430b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Connected-Pathology&lt;/div&gt;`)[0];
#                 popup_4b3ecc48913be159af931ad4656715fe.setContent(html_5063476c22092b7ca445756a541430b3);
#
#
#
#         marker_e816287f0a812e5dfe2c7b89ee35dcaa.bindPopup(popup_4b3ecc48913be159af931ad4656715fe)
#         ;
#
#
#
#
#             var marker_8397f432c8b991e6305a89f9de6f4ea8 = L.marker(
#                 [50.6365628, 4.6127019],
#                 {}
#             ).addTo(map_65e23a90628a36e5c86aff245cfdce84);

# %%
import pandas as pd
import folium

def load_data():
    path = "C:/Users/emine/Documents/Ecole/A5/Webscraping & Data Processing/Project/data/Startup database final.xlsx"
    data = pd.read_excel(path)
    return data

def get_location(address):
    pass

df = load_data()


sector = st.selectbox('Choisissez un secteur', df['sector'].unique())


filtered_data = df[df['sector'] == sector]


st.subheader(f'Données pour le secteur : {sector}')
st.write(filtered_data[['name', 'phone', 'size', 'website', 'founded', 'location']])


map = folium.Map(location=[20, 0], zoom_start=2)
for _, row in filtered_data.iterrows():
    lat, lon = get_location(row['location'])
    if lat and lon:
        folium.Marker([lat, lon], popup=row['name']).add_to(map)




def load_coordinates():
    path = "C:\\Users\\emine\\Documents\\Ecole\\A5\\Webscraping & Data Processing\\Project\\data\\startup_coordinates.xlsx"
    data = pd.read_excel(path)
    return data


df_coordinates = load_coordinates()


map = folium.Map(location=[20, 0], zoom_start=2)


for _, row in df_coordinates.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['name']).add_to(map)


map
